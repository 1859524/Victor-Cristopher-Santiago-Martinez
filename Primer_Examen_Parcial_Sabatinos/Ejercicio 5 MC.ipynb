# %%
n=input("Ingrese el numero que calculará la suma de 1 hasta el numero ingresado: ")
gauss=(int(n)*(int(n)+1))/2;
print("La suma de 1 hasta el numero ",n," ingresado es igual a:",int(gauss))
# Out:
# Ingrese el numero que calculará la suma de 1 hasta el numero ingresado: 100
# La suma de 1 hasta el numero  100  ingresado es igual a: 5050
