# %%
#Ejercicio 1#   #Victor Cristopher Santiago Martinez, 1859524, 
a=input("¿Como te llamas?: ")
b=input("¿Cuantos años tienes?: ")
c=input("¿Cual es tu frase favorita?: ")
d=input("¿Quien es el autor de tu frase favorita?: ")
print("Mi nombre es " +a +", tengo " +b +" años de edad, mi frase favorita es " +c +" del autor " +d)
# Out:
# ¿Como te llamas?: Victor
# ¿Cuantos años tienes?: 20
# ¿Cual es tu frase favorita?: la mayonesa es un instrumento
# ¿Quien es el autor de tu frase favorita?: Patricio
# Mi nombre es Victor, tengo 20 años de edad, mi frase favorita es la mayonesa es un instrumento del autor Patricio

# %%
#Ejercicio 2#
e=input("Agrega un numero entero: ")
a=int(e)
f=input("Agrega otro numero entero: ")
b=int(f)
g=input("Agrega un numero flotante o decimal: ")
c=float(g)
h=input("Agrega otro numero flotante o decimal: ")
d=float(h)
print("La suma de ",e,"+",f," es igual a: ",(a+b))
print("La resta de ",e,"-",f," es igual a: ",(a-b))
print("La multiplicacion de ",e,"*",f," es igual a: ",(a*b))
print("La division de ",e,"/",f," es igual a: ",(a/b))
print("La suma de ",g,"+",h," es igual a: ",(c+d))
print("La resta de ",g,"-",h," es igual a: ",(c-d))
print("La multiplicacion de ",g,"*",h," es igual a: ",(c*d))
print("La division de ",g,"/",h," es igual a: ",(c/d))
# Out:
# Agrega un numero entero: 4
# Agrega otro numero entero: 5
# Agrega un numero flotante o decimal: 6.5
# Agrega otro numero flotante o decimal: 4.7
# La suma de  4 + 5  es igual a:  9
# La resta de  4 - 5  es igual a:  -1
# La multiplicacion de  4 * 5  es igual a:  20
# La division de  4 / 5  es igual a:  0.8
# La suma de  6.5 + 4.7  es igual a:  11.2
# La resta de  6.5 - 4.7  es igual a:  1.7999999999999998
# La multiplicacion de  6.5 * 4.7  es igual a:  30.55
# La division de  6.5 / 4.7  es igual a:  1.3829787234042552

# %%
#Ejercicio 3
a=input("Ingrese un valor en 'a' para sustituir en la expresion logica (a<b): ")
b=input("Ingrese un valor en 'b' para sustituir en la expresion logica (a==b): ")
print("Si ambas expresiones se evaluan con un AND el resultado es: ",(a<b and a==b))
print("Si ambas expresiones se evaluan con un OR el resultado es: ",(a<b or a==b))
print("Si ambas expresiones se evaluan con un Not el resultado es: ",(not a<b),"y",(not a==b))
# Out:
# Ingrese un valor en 'a' para sustituir en la expresion logica (a<b): 5
# Ingrese un valor en 'b' para sustituir en la expresion logica (a==b): 3
# Si ambas expresiones se evaluan con un AND el resultado es:  False
# Si ambas expresiones se evaluan con un OR el resultado es:  False
# Si ambas expresiones se evaluan con un Not el resultado es:  True y True
